# %%
# !pip install nltk textblob -q
import pandas as pd
import nltk
from textblob import TextBlob
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# Download required NLTK data
try:
    nltk.data.find('tokenizers/punkt')
except LookupError:
    nltk.download('punkt', quiet=True)

print("Libraries imported successfully")

# Sample review data
data = {
    "review": [
        "I love this product, it is amazing!",
        "This is the worst experience I ever had.",
        "The service was okay, not bad.",
        "Absolutely fantastic and wonderful!",
        "I am very disappointed and unhappy.",
        "It is average, nothing special."
    ]
}

df = pd.DataFrame(data)
print("\nSample Reviews:")
print(df)

# Sentiment analysis function
def get_sentiment(text):
    """
    Analyze sentiment of text using TextBlob
    Returns: 'Positive', 'Negative', or 'Neutral'
    """
    try:
        analysis = TextBlob(str(text))
        polarity = analysis.sentiment.polarity
        
        if polarity > 0:
            return "Positive"
        elif polarity < 0:
            return "Negative"
        else:
            return "Neutral"
    except Exception as e:
        print(f"Error analyzing sentiment: {e}")
        return "Neutral"

# Apply sentiment analysis
df["sentiment"] = df["review"].apply(get_sentiment)
print("\nReviews with Sentiment:")
print(df)

# Visualize sentiment distribution
plt.figure(figsize=(8, 5))
sns.countplot(x="sentiment", data=df, palette="viridis")
plt.title("Sentiment Analysis Result", fontsize=14, fontweight='bold')
plt.xlabel("Sentiment", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.tight_layout()
plt.show()

print("\nTask-4 Sentiment Analysis completed successfully")
# Out:
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: C:\Python313\python.exe -m pip install --upgrade pip
# Libraries imported successfully
#
# Sample Reviews:
#                                      review
# 0       I love this product, it is amazing!
# 1  This is the worst experience I ever had.
# 2            The service was okay, not bad.
# 3       Absolutely fantastic and wonderful!
# 4       I am very disappointed and unhappy.
# 5           It is average, nothing special.
#
# Reviews with Sentiment:
#                                      review sentiment
# 0       I love this product, it is amazing!  Positive
# 1  This is the worst experience I ever had.  Negative
# 2            The service was okay, not bad.  Positive
# 3       Absolutely fantastic and wonderful!  Positive
# 4       I am very disappointed and unhappy.  Negative
# 5           It is average, nothing special.  Positive
# Task-4 Sentiment Analysis completed successfully
